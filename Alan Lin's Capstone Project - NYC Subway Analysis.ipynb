# %% [markdown]
# # Project 1: New York City Subway Analysis

# %% [markdown]
# # Part 1. Annual Ridership Analysis

# %% [markdown]
# ## 1. Load Data

# %%
import pandas as pd

# %%
riderships_df = pd.read_csv('MTA Ridership Data.csv')

# %%
riderships_df
# Out:
#                                         Station  Unnamed: 1  Unnamed: 2  \
# 0                  138 St-Grand Concourse (4,5)         NaN         NaN
# 1                149 St-Grand Concourse (2,4,5)         NaN         NaN
# 2                 161 St-Yankee Stadium (B,D,4)         NaN         NaN
# 3                                    167 St (4)         NaN         NaN
# 4                                  167 St (B,D)         NaN         NaN
# ..                                          ...         ...         ...
# 419  Sutphin Blvd-Archer Av-JFK Airport (E,J,Z)         NaN         NaN
# 420                  Vernon Blvd-Jackson Av (7)         NaN         NaN
# 421                        Woodhaven Blvd (J,Z)         NaN         NaN
# 422                        Woodhaven Blvd (M,R)         NaN         NaN
# 423                          Woodside-61 St (7)         NaN         NaN
#
#        Boro       2014       2015       2016     2017     2018     2019  \
# ...

# %% [markdown]
# ## 2. Handling Null Value

# %%
riderships_df.describe()
# Out:
#        Unnamed: 1  Unnamed: 2          2014          2015          2016  \
# count         0.0         0.0  4.200000e+02  4.210000e+02  4.210000e+02
# mean          NaN         NaN  4.169576e+06  4.186525e+06  4.172909e+06
# std           NaN         NaN  5.966177e+06  5.991406e+06  5.923851e+06
# min           NaN         NaN  0.000000e+00  0.000000e+00  0.000000e+00
# 25%           NaN         NaN  1.392438e+06  1.395260e+06  1.358853e+06
# 50%           NaN         NaN  2.356916e+06  2.334271e+06  2.354421e+06
# 75%           NaN         NaN  4.561683e+06  4.584041e+06  4.564432e+06
# max           NaN         NaN  6.594873e+07  6.635921e+07  6.453151e+07
#
#                2017          2018          2019  2018-2019 Change
# count  4.240000e+02  4.240000e+02  4.240000e+02      4.240000e+02
# mean   4.073773e+06  3.962436e+06  4.004215e+06      4.177835e+04
# std    5.814644e+06  5.790270e+06  5.794431e+06      4.930611e+05
# ...

# %%
# There are some missing values in this data
riderships_df.isnull().sum()
# Out:
# Station               0
# Unnamed: 1          424
# Unnamed: 2          424
# Boro                  0
# 2014                  4
# 2015                  3
# 2016                  3
# 2017                  0
# 2018                  0
# 2019                  0
# 2018-2019 Change      0
# dtype: int64

# %%
# fill null values with 0
riderships_df = riderships_df.fillna(0)

# %%
riderships_df
# Out:
#                                         Station  Unnamed: 1  Unnamed: 2  \
# 0                  138 St-Grand Concourse (4,5)         0.0         0.0
# 1                149 St-Grand Concourse (2,4,5)         0.0         0.0
# 2                 161 St-Yankee Stadium (B,D,4)         0.0         0.0
# 3                                    167 St (4)         0.0         0.0
# 4                                  167 St (B,D)         0.0         0.0
# ..                                          ...         ...         ...
# 419  Sutphin Blvd-Archer Av-JFK Airport (E,J,Z)         0.0         0.0
# 420                  Vernon Blvd-Jackson Av (7)         0.0         0.0
# 421                        Woodhaven Blvd (J,Z)         0.0         0.0
# 422                        Woodhaven Blvd (M,R)         0.0         0.0
# 423                          Woodside-61 St (7)         0.0         0.0
#
#        Boro       2014       2015       2016     2017     2018     2019  \
# ...

# %%
# Let's check there is no missing values
riderships_df.isnull().sum()
# Out:
# Station             0
# Unnamed: 1          0
# Unnamed: 2          0
# Boro                0
# 2014                0
# 2015                0
# 2016                0
# 2017                0
# 2018                0
# 2019                0
# 2018-2019 Change    0
# dtype: int64

# %% [markdown]
# # 3. How many stations do each boro have?

# %%
riderships_df.groupby('Boro').count()
# Out:
#            Station  Unnamed: 1  Unnamed: 2  2014  2015  2016  2017  2018  \
# Boro
# Bronx           68          68          68    68    68    68    68    68
# Brooklyn       157         157         157   157   157   157   157   157
# Manhattan      121         121         121   121   121   121   121   121
# Queens          78          78          78    78    78    78    78    78
#
#            2019  2018-2019 Change
# Boro
# Bronx        68                68
# Brooklyn    157               157
# Manhattan   121               121
# Queens       78                78

# %% [markdown]
# Note:
# * Bronx has 68 unique stations
# * Brooklyn has 157 unique stations
# * Manhattan has 121 unique stations
# * Queens has 78 unique stations

# %% [markdown]
# # 4. Comparison the total annual riderships each year - from 2014 to 2019

# %%
# Total Ridership in 2014 - The total ridership in 2014 is 1751221791
total_2014 = sum(riderships_df['2014'])
total_2014
# Out:
# 1751221791.0

# %%
# Total Ridership in 2015 - The total ridership in 2015 is 1762527050
total_2015 = sum(riderships_df['2015'])
total_2015
# Out:
# 1762527050.0

# %%
# Change in 2014 and 2015
diff_2014_2015 = sum(riderships_df['2015']) - sum(riderships_df['2014'])
diff_2014_2015
# Out:
# 11305259.0

# %%
# Percentage Change between 2014 and 2015
change_2014_2015 = diff_2014_2015/sum(riderships_df['2014']) * 100
change_2014_2015
# Out:
# 0.6455640889178497

# %%
# Total Ridership in 2016 - The total ridership in 2016 is 1756794850
total_2016 = sum(riderships_df['2016'])
total_2016
# Out:
# 1756794850.0

# %%
# Change in 2015 and 2016
diff_2015_2016 = sum(riderships_df['2016']) - sum(riderships_df['2015'])
diff_2015_2016
# Out:
# -5732200.0

# %%
# Percentage Change between 2015 and 2016
change_2015_2016 = diff_2015_2016/sum(riderships_df['2015']) * 100
change_2015_2016
# Out:
# -0.32522621425866916

# %%
# Total Ridership in 2017 - The total ridership in 2017 is 1727279608
total_2017 = sum(riderships_df['2017'])
total_2017
# Out:
# 1727279608

# %%
# Change in 2016 and 2017
diff_2016_2017 = sum(riderships_df['2017']) - sum(riderships_df['2016'])
diff_2016_2017
# Out:
# -29515242.0

# %%
# Percentage Change between 2016 and 2017
change_2016_2017 = diff_2016_2017/sum(riderships_df['2016']) * 100
change_2016_2017
# Out:
# -1.6800619605641491

# %%
# Total Ridership in 2018 - The total ridership in 2018 is 1680072981
total_2018 = sum(riderships_df['2018'])
total_2018
# Out:
# 1680072981

# %%
# Change in 2017 and 2018
diff_2017_2018 = sum(riderships_df['2018']) - sum(riderships_df['2017'])
diff_2017_2018
# Out:
# -47206627

# %%
# Percentage Change between 2017 and 2018
change_2017_2018 = diff_2017_2018/sum(riderships_df['2017']) * 100
change_2017_2018
# Out:
# -2.733004360229789

# %%
# Total Ridership in 2019 - The total ridership in 2019 is 1697787002
total_2019 = sum(riderships_df['2019'])
total_2019
# Out:
# 1697787002

# %%
# Change in 2018 and 2019
diff_2018_2019 = sum(riderships_df['2019']) - sum(riderships_df['2018'])
diff_2018_2019
# Out:
# 17714021

# %%
# Percentage Change between 2018 and 2019
change_2018_2019 = diff_2018_2019/sum(riderships_df['2018']) * 100
change_2018_2019
# Out:
# 1.0543602093675952

# %%
import plotly.express as px

# %%
year = [2014,2015,2016,2017,2018,2019]
total_riderships = [sum(riderships_df['2014']), sum(riderships_df['2015']), sum(riderships_df['2016']), \
                  sum(riderships_df['2017']), sum(riderships_df['2018']), sum(riderships_df['2019'])]
fig = px.bar(x= year, y = total_ridership, title="Riderships between 2014-2019")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="679363ad-3bc9-4cbf-9aeb-05a8353dfd44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("679363ad-3bc9-4cbf-9aeb-05a8353dfd44")) {                    Plotly.newPlot(                        "679363ad-3bc9-4cbf-9aeb-05a8353dfd44",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [2014, 2015, 2016, 2017, 2018, 2019], "xaxis": "x", "y": [1751221791.0, 1762527050.0, 1756794850.0, 1727279608.0, 1680072981.0, 1697787002.0], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"tra
# ...

# %%
total_riderships
# Out:
# [1751221791.0, 1762527050.0, 1756794850.0, 1727279608, 1680072981, 1697787002]

# %% [markdown]
# # 5. Riderships by Boro each year (2014-2019)

# %%
fig = px.bar(x=riderships_df['Boro'] , y = riderships_df['2014'], title="Riderships in 2014")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="71b0dd68-c331-4480-abf9-5b8617fad716" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("71b0dd68-c331-4480-abf9-5b8617fad716")) {                    Plotly.newPlot(                        "71b0dd68-c331-4480-abf9-5b8617fad716",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bro
# ...

# %%
fig = px.bar(x=riderships_df['Boro'] , y = riderships_df['2015'], title="Riderships in 2015")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="11ef6f6d-68b3-48d4-a63e-28d5af409b01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11ef6f6d-68b3-48d4-a63e-28d5af409b01")) {                    Plotly.newPlot(                        "11ef6f6d-68b3-48d4-a63e-28d5af409b01",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bro
# ...

# %%
fig = px.bar(x=riderships_df['Boro'] , y = riderships_df['2016'], title="Riderships in 2016")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="64392ede-0208-4b62-92e7-6106ad5bf905" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64392ede-0208-4b62-92e7-6106ad5bf905")) {                    Plotly.newPlot(                        "64392ede-0208-4b62-92e7-6106ad5bf905",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bro
# ...

# %%
fig = px.bar(x=riderships_df['Boro'] , y = riderships_df['2017'], title="Riderships in 2017")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="2178960c-0ed0-4ebe-9dde-5e10ca89f2a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2178960c-0ed0-4ebe-9dde-5e10ca89f2a3")) {                    Plotly.newPlot(                        "2178960c-0ed0-4ebe-9dde-5e10ca89f2a3",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bro
# ...

# %%
fig = px.bar(x=riderships_df['Boro'] , y = riderships_df['2018'], title="Riderships in 2018")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="f84f1b96-41f8-44f8-a2ab-6988a5e38c45" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f84f1b96-41f8-44f8-a2ab-6988a5e38c45")) {                    Plotly.newPlot(                        "f84f1b96-41f8-44f8-a2ab-6988a5e38c45",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bro
# ...

# %%
fig = px.bar(x=riderships_df['Boro'] , y = riderships_df['2019'], title="Riderships in 2019")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="89d769fd-7950-4729-b5ea-2b3ab2b06beb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89d769fd-7950-4729-b5ea-2b3ab2b06beb")) {                    Plotly.newPlot(                        "89d769fd-7950-4729-b5ea-2b3ab2b06beb",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bronx", "Bro
# ...

# %% [markdown]
# # 6. Ridership Analysis - Find 20 stations have highest ridership each year, and 20 stations have lower ridership each year between 2014-2019

# %% [markdown]
# ### (1) 20 highest riderships in 2014

# %%
# Let's find out 20 stations have highest riderships in 2014
riderships_2014_high = riderships_df.sort_values(by=['2014'], ascending = False).head(20)
riderships_2014_high
# Out:
#                                                Station  Unnamed: 1  \
# 341   Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)         0.0
# 325                    Grand Central-42 St (S,4,5,6,7)         0.0
# 271                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)         0.0
# 243                   14 St-Union Sq (L,N,Q,R,W,4,5,6)         0.0
# 273                         34 St-Penn Station (1,2,3)         0.0
# 274                         34 St-Penn Station (A,C,E)         0.0
# 284                  59 St-Columbus Circle (A,B,C,D,1)         0.0
# 330                 Lexington Av (N,R,W)/59 St (4,5,6)         0.0
# 296                                      86 St (4,5,6)         0.0
# 331                 Lexington Av-53 St (E,M)/51 St (6)         0.0
# 324                        Fulton St (A,C,J,Z,2,3,4,5)         0.0
# 395                               Flushing-Main St (7)         0.0
# 276             47-50 Sts-Rockefeller Center (B,D,F,M)         0.0
# ...

# %%
# Get the highest ridership in 2014 respective to stations
high_station_2014 = riderships_2014_high['Station']

# %%
high_station_2014
# Out:
# 341     Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 325                      Grand Central-42 St (S,4,5,6,7)
# 271                    34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 243                     14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 273                           34 St-Penn Station (1,2,3)
# 274                           34 St-Penn Station (A,C,E)
# 284                    59 St-Columbus Circle (A,B,C,D,1)
# 330                   Lexington Av (N,R,W)/59 St (4,5,6)
# 296                                        86 St (4,5,6)
# 331                   Lexington Av-53 St (E,M)/51 St (6)
# 324                          Fulton St (A,C,J,Z,2,3,4,5)
# 395                                 Flushing-Main St (7)
# 276               47-50 Sts-Rockefeller Center (B,D,F,M)
# 316    Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 369    74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...
# 242                           14 St (F,M,1,2,3)/6 Av (L)
# ...

# %%
high_station_2014.unique()
# Out:
# array(['Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', '34 St-Penn Station (1,2,3)',
#        '34 St-Penn Station (A,C,E)', '59 St-Columbus Circle (A,B,C,D,1)',
#        'Lexington Av (N,R,W)/59 St (4,5,6)', '86 St (4,5,6)',
#        'Lexington Av-53 St (E,M)/51 St (6)',
#        'Fulton St (A,C,J,Z,2,3,4,5)', 'Flushing-Main St (7)',
#        '47-50 Sts-Rockefeller Center (B,D,F,M)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        '14 St (F,M,1,2,3)/6 Av (L)', '42 St-Bryant Pk (B,D,F,M)/5 Av (7)',
#        'Canal St (J,N,Q,R,W,Z,6)', '14 St (A,C,E)/8 Av (L)',
#        'West 4 St-Washington Sq (A,B,C,D,E,F,M)'], dtype=object)

# %%
# Get the highest ridership unique values in 2014 respective to stations
riderships_2014_high = riderships_2014_high['2014']

# %%
riderships_2014_high
# Out:
# 341    65948730.0
# 325    46074652.0
# 271    39285568.0
# 243    35677468.0
# 273    28638643.0
# 274    26493571.0
# 284    23566961.0
# 330    21557198.0
# 296    20735032.0
# 331    20513370.0
# 324    20102397.0
# 395    19085948.0
# 276    18236646.0
# 316    17589023.0
# 369    17087795.0
# 242    16215866.0
# 275    15896805.0
# 311    15104077.0
# 241    14340856.0
# 344    13942101.0
# Name: 2014, dtype: float64

# %%
riderships_2014_high.unique()
# Out:
# array([65948730., 46074652., 39285568., 35677468., 28638643., 26493571.,
#        23566961., 21557198., 20735032., 20513370., 20102397., 19085948.,
#        18236646., 17589023., 17087795., 16215866., 15896805., 15104077.,
#        14340856., 13942101.])

# %%
fig = px.bar(x=high_station_2014, y = riderships_2014_high, title="20 Busiest Station in 2014")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="cde35ac5-239c-474e-8399-93f4398f2867" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cde35ac5-239c-474e-8399-93f4398f2867")) {                    Plotly.newPlot(                        "cde35ac5-239c-474e-8399-93f4398f2867",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)", "Grand Central-42 St (S,4,5,6,7)", "34 St-Herald Sq (B,D,F,M,N,Q,R,W)", "14 St-Union Sq (L,N,Q,R,W,4,5,6)", "34 St-Penn Station (1,2,3)", "34 St-Penn Station (A,C,E)", 
# ...

# %% [markdown]
# ### (2) 20 lowest riderships in 2014

# %%
# Let's find out 20 stations have lowest riderships in 2014
riderships_2014_low = riderships_df.sort_values(by=['2014'], ascending = False).tail(20)
riderships_2014_low
# Out:
#                               Station  Unnamed: 1  Unnamed: 2       Boro  \
# 382                   Beach 25 St (A)         0.0         0.0     Queens
# 189                    Neptune Av (F)         0.0         0.0   Brooklyn
# 107                      Bay Pkwy (F)         0.0         0.0   Brooklyn
# 138                 Cypress Hills (J)         0.0         0.0   Brooklyn
# 354                         21 St (G)         0.0         0.0     Queens
# 347                        104 St (A)         0.0         0.0     Queens
# 378     Aqueduct-North Conduit Av (A)         0.0         0.0     Queens
# 387                 Beach 90 St (A,S)         0.0         0.0     Queens
# 30       East 143 St-St Mary's St (6)         0.0         0.0      Bronx
# 383                   Beach 36 St (A)         0.0         0.0     Queens
# 415  Rockaway Park-Beach 116 St (A,S)         0.0         0.0     Queens
# 388                 Beach 98 St (A,S)         0.0         0.0     Queens
# ...

# %%
# Get the lowest ridership in 2014 respective to stations
low_station_2014 = riderships_2014_low['Station']

# %%
low_station_2014
# Out:
# 382                     Beach 25 St (A)
# 189                      Neptune Av (F)
# 107                        Bay Pkwy (F)
# 138                   Cypress Hills (J)
# 354                           21 St (G)
# 347                          104 St (A)
# 378       Aqueduct-North Conduit Av (A)
# 387                   Beach 90 St (A,S)
# 30         East 143 St-St Mary's St (6)
# 383                     Beach 36 St (A)
# 415    Rockaway Park-Beach 116 St (A,S)
# 388                   Beach 98 St (A,S)
# 384                     Beach 44 St (A)
# 381                  Beach 105 St (A,S)
# 390                 Broad Channel (A,S)
# 298                           86 St (Q)
# 345                   WTC Cortlandt (1)
# 302                           96 St (Q)
# 272              34 St-Hudson Yards (7)
# 290                           72 St (Q)
# Name: Station, dtype: object

# %%
low_station_2014.unique()
# Out:
# array(['Beach 25 St (A)', 'Neptune Av (F)', 'Bay Pkwy (F)',
#        'Cypress Hills (J)', '21 St (G)', '104 St (A)',
#        'Aqueduct-North Conduit Av (A)', 'Beach 90 St (A,S)',
#        "East 143 St-St Mary's St (6)", 'Beach 36 St (A)',
#        'Rockaway Park-Beach 116 St (A,S)', 'Beach 98 St (A,S)',
#        'Beach 44 St (A)', 'Beach 105 St (A,S)', 'Broad Channel (A,S)',
#        '86 St (Q)', 'WTC Cortlandt (1)', '96 St (Q)',
#        '34 St-Hudson Yards (7)', '72 St (Q)'], dtype=object)

# %%
# Get the lowest ridership unique values in 2014 respective to stations
riderships_2014_low = riderships_2014_low['2014']

# %%
riderships_2014_low
# Out:
# 382    519843.0
# 189    512828.0
# 107    478322.0
# 138    450480.0
# 354    427353.0
# 347    388144.0
# 378    357399.0
# 387    306284.0
# 30     279012.0
# 383    272799.0
# 415    231407.0
# 388    200197.0
# 384    181758.0
# 381     82980.0
# 390     74386.0
# 298         0.0
# 345         0.0
# 302         0.0
# 272         0.0
# 290         0.0
# Name: 2014, dtype: float64

# %%
riderships_2014_low.unique()
# Out:
# array([519843., 512828., 478322., 450480., 427353., 388144., 357399.,
#        306284., 279012., 272799., 231407., 200197., 181758.,  82980.,
#         74386.,      0.])

# %%
fig = px.bar(x=low_station_2014, y = riderships_2014_low, title="20 Least Riderships Station in 2014")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="44bc970c-24cc-414b-ac66-04c46cf48e3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44bc970c-24cc-414b-ac66-04c46cf48e3e")) {                    Plotly.newPlot(                        "44bc970c-24cc-414b-ac66-04c46cf48e3e",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Beach 25 St (A)", "Neptune Av (F)", "Bay Pkwy (F)", "Cypress Hills (J)", "21 St (G)", "104 St (A)", "Aqueduct-North Conduit Av (A)", "Beach 90 St (A,S)", "East 143 St-St Mary's St (6)", "Beach 36 St (A)", "Rockaway Park
# ...

# %%
# Average Ridership in 2014
int(riderships_df['2014'].mean())
# Out:
# 4130240

# %%
# Average Ridership in 20 Busiest Station in 2014
int(riderships_2014_high.mean())
# Out:
# 24804635

# %%
# Average Ridership in 20 Least Business Station in 2014
int(riderships_2014_low.mean())
# Out:
# 238159

# %% [markdown]
# ### (3) 20 highest riderships in 2015

# %%
# Let's find out 20 stations have highest riderships in 2015
riderships_2015_high = riderships_df.sort_values(by=['2015'], ascending = False).head(20)
riderships_2015_high
# Out:
#                                                Station  Unnamed: 1  \
# 341   Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)         0.0
# 325                    Grand Central-42 St (S,4,5,6,7)         0.0
# 271                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)         0.0
# 243                   14 St-Union Sq (L,N,Q,R,W,4,5,6)         0.0
# 273                         34 St-Penn Station (1,2,3)         0.0
# 274                         34 St-Penn Station (A,C,E)         0.0
# 284                  59 St-Columbus Circle (A,B,C,D,1)         0.0
# 324                        Fulton St (A,C,J,Z,2,3,4,5)         0.0
# 330                 Lexington Av (N,R,W)/59 St (4,5,6)         0.0
# 296                                      86 St (4,5,6)         0.0
# 331                 Lexington Av-53 St (E,M)/51 St (6)         0.0
# 316  Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...         0.0
# 395                               Flushing-Main St (7)         0.0
# ...

# %%
# Get the highest ridership unique values in 2015 respective to stations
high_station_2015 = riderships_2015_high['Station']

# %%
high_station_2015
# Out:
# 341     Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 325                      Grand Central-42 St (S,4,5,6,7)
# 271                    34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 243                     14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 273                           34 St-Penn Station (1,2,3)
# 274                           34 St-Penn Station (A,C,E)
# 284                    59 St-Columbus Circle (A,B,C,D,1)
# 324                          Fulton St (A,C,J,Z,2,3,4,5)
# 330                   Lexington Av (N,R,W)/59 St (4,5,6)
# 296                                        86 St (4,5,6)
# 331                   Lexington Av-53 St (E,M)/51 St (6)
# 316    Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 395                                 Flushing-Main St (7)
# 276               47-50 Sts-Rockefeller Center (B,D,F,M)
# 369    74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...
# 275                   42 St-Bryant Pk (B,D,F,M)/5 Av (7)
# ...

# %%
high_station_2015.unique()
# Out:
# array(['Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', '34 St-Penn Station (1,2,3)',
#        '34 St-Penn Station (A,C,E)', '59 St-Columbus Circle (A,B,C,D,1)',
#        'Fulton St (A,C,J,Z,2,3,4,5)',
#        'Lexington Av (N,R,W)/59 St (4,5,6)', '86 St (4,5,6)',
#        'Lexington Av-53 St (E,M)/51 St (6)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        'Flushing-Main St (7)', '47-50 Sts-Rockefeller Center (B,D,F,M)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        '42 St-Bryant Pk (B,D,F,M)/5 Av (7)', '14 St (F,M,1,2,3)/6 Av (L)',
#        'Canal St (J,N,Q,R,W,Z,6)', '14 St (A,C,E)/8 Av (L)',
#        'West 4 St-Washington Sq (A,B,C,D,E,F,M)'], dtype=object)

# %%
# Get the highest ridership unique values in 2015 respective to stations
riderships_2015_high = riderships_2015_high['2015']

# %%
riderships_2015_high
# Out:
# 341    66359208.0
# 325    46737564.0
# 271    39541865.0
# 243    35320623.0
# 273    28309160.0
# 274    26147434.0
# 284    23299666.0
# 324    21671684.0
# 330    21407792.0
# 296    20890828.0
# 331    20479923.0
# 316    19623616.0
# 395    19082391.0
# 276    18469446.0
# 369    17224537.0
# 275    16220605.0
# 242    16121318.0
# 311    15094135.0
# 241    14763727.0
# 344    14147148.0
# Name: 2015, dtype: float64

# %%
# Get the highest ridership unique values in 2014 respective to stations
riderships_2015_high.unique()
# Out:
# array([66359208., 46737564., 39541865., 35320623., 28309160., 26147434.,
#        23299666., 21671684., 21407792., 20890828., 20479923., 19623616.,
#        19082391., 18469446., 17224537., 16220605., 16121318., 15094135.,
#        14763727., 14147148.])

# %%
fig = px.bar(x=high_station_2015, y = riderships_2015_high, title="20 Busiest Station in 2015")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="7ffab5ad-868d-4954-84d7-8d201e9953f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ffab5ad-868d-4954-84d7-8d201e9953f5")) {                    Plotly.newPlot(                        "7ffab5ad-868d-4954-84d7-8d201e9953f5",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)", "Grand Central-42 St (S,4,5,6,7)", "34 St-Herald Sq (B,D,F,M,N,Q,R,W)", "14 St-Union Sq (L,N,Q,R,W,4,5,6)", "34 St-Penn Station (1,2,3)", "34 St-Penn Station (A,C,E)", 
# ...

# %% [markdown]
# ### (4) 20 lowest riderships in 2015

# %%
# Let's find out 20 stations have lowest riderships in 2015
riderships_2015_low = riderships_df.sort_values(by=['2015'], ascending = False).tail(20)
riderships_2015_low
# Out:
#                               Station  Unnamed: 1  Unnamed: 2       Boro  \
# 189                    Neptune Av (F)         0.0         0.0   Brooklyn
# 207                   Rockaway Av (3)         0.0         0.0   Brooklyn
# 67                      Zerega Av (6)         0.0         0.0      Bronx
# 107                      Bay Pkwy (F)         0.0         0.0   Brooklyn
# 138                 Cypress Hills (J)         0.0         0.0   Brooklyn
# 93                    Atlantic Av (L)         0.0         0.0   Brooklyn
# 378     Aqueduct-North Conduit Av (A)         0.0         0.0     Queens
# 387                 Beach 90 St (A,S)         0.0         0.0     Queens
# 218                 Van Siclen Av (3)         0.0         0.0   Brooklyn
# 30       East 143 St-St Mary's St (6)         0.0         0.0      Bronx
# 383                   Beach 36 St (A)         0.0         0.0     Queens
# 415  Rockaway Park-Beach 116 St (A,S)         0.0         0.0     Queens
# ...

# %%
# Get the lowest ridership unique values in 2015 respective to stations
low_station_2015 = riderships_2015_low['Station']

# %%
low_station_2015
# Out:
# 189                      Neptune Av (F)
# 207                     Rockaway Av (3)
# 67                        Zerega Av (6)
# 107                        Bay Pkwy (F)
# 138                   Cypress Hills (J)
# 93                      Atlantic Av (L)
# 378       Aqueduct-North Conduit Av (A)
# 387                   Beach 90 St (A,S)
# 218                   Van Siclen Av (3)
# 30         East 143 St-St Mary's St (6)
# 383                     Beach 36 St (A)
# 415    Rockaway Park-Beach 116 St (A,S)
# 388                   Beach 98 St (A,S)
# 384                     Beach 44 St (A)
# 381                  Beach 105 St (A,S)
# 390                 Broad Channel (A,S)
# 345                   WTC Cortlandt (1)
# 302                           96 St (Q)
# 298                           86 St (Q)
# 290                           72 St (Q)
# Name: Station, dtype: object

# %%
low_station_2015.unique()
# Out:
# array(['Neptune Av (F)', 'Rockaway Av (3)', 'Zerega Av (6)',
#        'Bay Pkwy (F)', 'Cypress Hills (J)', 'Atlantic Av (L)',
#        'Aqueduct-North Conduit Av (A)', 'Beach 90 St (A,S)',
#        'Van Siclen Av (3)', "East 143 St-St Mary's St (6)",
#        'Beach 36 St (A)', 'Rockaway Park-Beach 116 St (A,S)',
#        'Beach 98 St (A,S)', 'Beach 44 St (A)', 'Beach 105 St (A,S)',
#        'Broad Channel (A,S)', 'WTC Cortlandt (1)', '96 St (Q)',
#        '86 St (Q)', '72 St (Q)'], dtype=object)

# %%
# Get the lowest ridership unique values in 2015 respective to stations
riderships_2015_low = riderships_2015_low['2015']

# %%
riderships_2015_low
# Out:
# 189    531011.0
# 207    526505.0
# 67     492883.0
# 107    460536.0
# 138    452936.0
# 93     422505.0
# 378    365488.0
# 387    333006.0
# 218    304082.0
# 30     298462.0
# 383    296860.0
# 415    255542.0
# 388    214040.0
# 384    197543.0
# 381     99254.0
# 390     91766.0
# 345         0.0
# 302         0.0
# 298         0.0
# 290         0.0
# Name: 2015, dtype: float64

# %%
riderships_2015_low.unique()
# Out:
# array([531011., 526505., 492883., 460536., 452936., 422505., 365488.,
#        333006., 304082., 298462., 296860., 255542., 214040., 197543.,
#         99254.,  91766.,      0.])

# %%
fig = px.bar(x=low_station_2015, y = riderships_2015_low, title="20 Least Riderships Station in 2015")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="9f01ae3d-24ed-4914-8a04-79491fd1d3de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9f01ae3d-24ed-4914-8a04-79491fd1d3de")) {                    Plotly.newPlot(                        "9f01ae3d-24ed-4914-8a04-79491fd1d3de",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Neptune Av (F)", "Rockaway Av (3)", "Zerega Av (6)", "Bay Pkwy (F)", "Cypress Hills (J)", "Atlantic Av (L)", "Aqueduct-North Conduit Av (A)", "Beach 90 St (A,S)", "Van Siclen Av (3)", "East 143 St-St Mary's St (6)", "Be
# ...

# %%
# Average Ridership in 2015
int(riderships_df['2015'].mean())
# Out:
# 4156903

# %%
# Average Ridership in 20 Busiest Station in 2015
int(riderships_2015_high.mean())
# Out:
# 25045633

# %%
# Average Ridership in 20 Least Busiest Station in 2015
int(riderships_2015_low.mean())
# Out:
# 267120

# %% [markdown]
# ### (5) 20 highest riderships in 2016

# %%
# Let's find out 20 stations have highest riderships in 2016
riderships_2016_high = riderships_df.sort_values(by=['2016'], ascending = False).head(20)
riderships_2016_high
# Out:
#                                                Station  Unnamed: 1  \
# 341   Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)         0.0
# 325                    Grand Central-42 St (S,4,5,6,7)         0.0
# 271                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)         0.0
# 243                   14 St-Union Sq (L,N,Q,R,W,4,5,6)         0.0
# 273                         34 St-Penn Station (1,2,3)         0.0
# 274                         34 St-Penn Station (A,C,E)         0.0
# 324                        Fulton St (A,C,J,Z,2,3,4,5)         0.0
# 284                  59 St-Columbus Circle (A,B,C,D,1)         0.0
# 330                 Lexington Av (N,R,W)/59 St (4,5,6)         0.0
# 316  Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...         0.0
# 296                                      86 St (4,5,6)         0.0
# 331                 Lexington Av-53 St (E,M)/51 St (6)         0.0
# 395                               Flushing-Main St (7)         0.0
# ...

# %%
# Get the highest ridership unique values in 2016 respective to stations
high_station_2016 = riderships_2016_high['Station']

# %%
high_station_2016
# Out:
# 341     Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 325                      Grand Central-42 St (S,4,5,6,7)
# 271                    34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 243                     14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 273                           34 St-Penn Station (1,2,3)
# 274                           34 St-Penn Station (A,C,E)
# 324                          Fulton St (A,C,J,Z,2,3,4,5)
# 284                    59 St-Columbus Circle (A,B,C,D,1)
# 330                   Lexington Av (N,R,W)/59 St (4,5,6)
# 316    Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 296                                        86 St (4,5,6)
# 331                   Lexington Av-53 St (E,M)/51 St (6)
# 395                                 Flushing-Main St (7)
# 276               47-50 Sts-Rockefeller Center (B,D,F,M)
# 369    74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...
# 275                   42 St-Bryant Pk (B,D,F,M)/5 Av (7)
# ...

# %%
high_station_2016.unique()
# Out:
# array(['Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', '34 St-Penn Station (1,2,3)',
#        '34 St-Penn Station (A,C,E)', 'Fulton St (A,C,J,Z,2,3,4,5)',
#        '59 St-Columbus Circle (A,B,C,D,1)',
#        'Lexington Av (N,R,W)/59 St (4,5,6)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        '86 St (4,5,6)', 'Lexington Av-53 St (E,M)/51 St (6)',
#        'Flushing-Main St (7)', '47-50 Sts-Rockefeller Center (B,D,F,M)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        '42 St-Bryant Pk (B,D,F,M)/5 Av (7)', '14 St (F,M,1,2,3)/6 Av (L)',
#        'Canal St (J,N,Q,R,W,Z,6)', '14 St (A,C,E)/8 Av (L)',
#        'West 4 St-Washington Sq (A,B,C,D,E,F,M)'], dtype=object)

# %%
# Get the highest ridership unique values in 2016 respective to stations
riderships_2016_high = riderships_2016_high['2016']

# %%
riderships_2016_high
# Out:
# 341    64531511.0
# 325    46121509.0
# 271    39000352.0
# 243    34289822.0
# 273    27741367.0
# 274    25183869.0
# 324    25162937.0
# 284    23203443.0
# 330    21000635.0
# 316    20349660.0
# 296    20337593.0
# 331    19929405.0
# 395    19257879.0
# 276    18086203.0
# 369    17301839.0
# 275    16934142.0
# 242    16118952.0
# 311    15274896.0
# 241    14572075.0
# 344    13955067.0
# Name: 2016, dtype: float64

# %%
riderships_2016_high.unique()
# Out:
# array([64531511., 46121509., 39000352., 34289822., 27741367., 25183869.,
#        25162937., 23203443., 21000635., 20349660., 20337593., 19929405.,
#        19257879., 18086203., 17301839., 16934142., 16118952., 15274896.,
#        14572075., 13955067.])

# %%
fig = px.bar(x=high_station_2016, y = riderships_2016_high, title="20 Busiest Station in 2016")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="0404abc3-439f-4aa8-8dc8-0589b32cd33f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0404abc3-439f-4aa8-8dc8-0589b32cd33f")) {                    Plotly.newPlot(                        "0404abc3-439f-4aa8-8dc8-0589b32cd33f",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)", "Grand Central-42 St (S,4,5,6,7)", "34 St-Herald Sq (B,D,F,M,N,Q,R,W)", "14 St-Union Sq (L,N,Q,R,W,4,5,6)", "34 St-Penn Station (1,2,3)", "34 St-Penn Station (A,C,E)", 
# ...

# %% [markdown]
# ### (6) 20 lowest riderships in 2016

# %%
# Let's find out 20 stations have lowest riderships in 2016
riderships_2016_low = riderships_df.sort_values(by=['2016'], ascending = False).tail(20)
riderships_2016_low
# Out:
#                               Station  Unnamed: 1  Unnamed: 2       Boro  \
# 171                     Kings Hwy (N)         0.0         0.0   Brooklyn
# 138                 Cypress Hills (J)         0.0         0.0   Brooklyn
# 102                      Avenue U (N)         0.0         0.0   Brooklyn
# 93                    Atlantic Av (L)         0.0         0.0   Brooklyn
# 89                          86 St (N)         0.0         0.0   Brooklyn
# 73                          20 Av (N)         0.0         0.0   Brooklyn
# 107                      Bay Pkwy (F)         0.0         0.0   Brooklyn
# 378     Aqueduct-North Conduit Av (A)         0.0         0.0     Queens
# 387                 Beach 90 St (A,S)         0.0         0.0     Queens
# 30       East 143 St-St Mary's St (6)         0.0         0.0      Bronx
# 383                   Beach 36 St (A)         0.0         0.0     Queens
# 415  Rockaway Park-Beach 116 St (A,S)         0.0         0.0     Queens
# ...

# %%
# Get the lowest ridership unique values in 2016 respective to stations
low_station_2016 = riderships_2016_low['Station']

# %%
low_station_2016
# Out:
# 171                       Kings Hwy (N)
# 138                   Cypress Hills (J)
# 102                        Avenue U (N)
# 93                      Atlantic Av (L)
# 89                            86 St (N)
# 73                            20 Av (N)
# 107                        Bay Pkwy (F)
# 378       Aqueduct-North Conduit Av (A)
# 387                   Beach 90 St (A,S)
# 30         East 143 St-St Mary's St (6)
# 383                     Beach 36 St (A)
# 415    Rockaway Park-Beach 116 St (A,S)
# 384                     Beach 44 St (A)
# 388                   Beach 98 St (A,S)
# 381                  Beach 105 St (A,S)
# 390                 Broad Channel (A,S)
# 298                           86 St (Q)
# 345                   WTC Cortlandt (1)
# 290                           72 St (Q)
# 302                           96 St (Q)
# Name: Station, dtype: object

# %%
low_station_2016.unique()
# Out:
# array(['Kings Hwy (N)', 'Cypress Hills (J)', 'Avenue U (N)',
#        'Atlantic Av (L)', '86 St (N)', '20 Av (N)', 'Bay Pkwy (F)',
#        'Aqueduct-North Conduit Av (A)', 'Beach 90 St (A,S)',
#        "East 143 St-St Mary's St (6)", 'Beach 36 St (A)',
#        'Rockaway Park-Beach 116 St (A,S)', 'Beach 44 St (A)',
#        'Beach 98 St (A,S)', 'Beach 105 St (A,S)', 'Broad Channel (A,S)',
#        '86 St (Q)', 'WTC Cortlandt (1)', '72 St (Q)', '96 St (Q)'],
#       dtype=object)

# %%
# Get the lowest ridership unique values in 2016 respective to stations
riderships_2016_low = riderships_2016_low['2016']

# %%
riderships_2016_low
# Out:
# 171    475763.0
# 138    462143.0
# 102    456533.0
# 93     436300.0
# 89     419039.0
# 73     409416.0
# 107    406793.0
# 378    342494.0
# 387    335515.0
# 30     313386.0
# 383    305816.0
# 415    250220.0
# 384    212440.0
# 388    203795.0
# 381     95469.0
# 390     91208.0
# 298         0.0
# 345         0.0
# 290         0.0
# 302         0.0
# Name: 2016, dtype: float64

# %%
riderships_2016_low.unique()
# Out:
# array([475763., 462143., 456533., 436300., 419039., 409416., 406793.,
#        342494., 335515., 313386., 305816., 250220., 212440., 203795.,
#         95469.,  91208.,      0.])

# %%
fig = px.bar(x=low_station_2016, y = riderships_2016_low, title="20 Least Riderships Station in 2016")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="bbe9e581-dd50-43cb-8529-c51a44f40534" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbe9e581-dd50-43cb-8529-c51a44f40534")) {                    Plotly.newPlot(                        "bbe9e581-dd50-43cb-8529-c51a44f40534",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Kings Hwy (N)", "Cypress Hills (J)", "Avenue U (N)", "Atlantic Av (L)", "86 St (N)", "20 Av (N)", "Bay Pkwy (F)", "Aqueduct-North Conduit Av (A)", "Beach 90 St (A,S)", "East 143 St-St Mary's St (6)", "Beach 36 St (A)", 
# ...

# %%
# Average Ridership in 2016
int(riderships_df['2016'].mean())
# Out:
# 4143384

# %%
# Average Ridership in 20 Busiest Station in 2016
int(riderships_2016_high.mean())
# Out:
# 24917657

# %%
# Average Ridership in 20 Least Busiest Station in 2016
int(riderships_2016_low.mean())
# Out:
# 260816

# %% [markdown]
# ### (7) 20 highest riderships in 2017

# %%
# Let's find out 20 stations have highest riderships in 2017
riderships_2017_high = riderships_df.sort_values(by=['2017'], ascending = False).head(20)
riderships_2017_high
# Out:
#                                                Station  Unnamed: 1  \
# 341   Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)         0.0
# 325                    Grand Central-42 St (S,4,5,6,7)         0.0
# 271                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)         0.0
# 243                   14 St-Union Sq (L,N,Q,R,W,4,5,6)         0.0
# 324                        Fulton St (A,C,J,Z,2,3,4,5)         0.0
# 273                         34 St-Penn Station (1,2,3)         0.0
# 274                         34 St-Penn Station (A,C,E)         0.0
# 284                  59 St-Columbus Circle (A,B,C,D,1)         0.0
# 316  Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...         0.0
# 331                 Lexington Av-53 St (E,M)/51 St (6)         0.0
# 395                               Flushing-Main St (7)         0.0
# 330                 Lexington Av (N,R,W)/59 St (4,5,6)         0.0
# 276             47-50 Sts-Rockefeller Center (B,D,F,M)         0.0
# ...

# %%
# Get the highest ridership unique values in 2017 respective to stations
high_station_2017 = riderships_2017_high['Station']

# %%
high_station_2017
# Out:
# 341     Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 325                      Grand Central-42 St (S,4,5,6,7)
# 271                    34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 243                     14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 324                          Fulton St (A,C,J,Z,2,3,4,5)
# 273                           34 St-Penn Station (1,2,3)
# 274                           34 St-Penn Station (A,C,E)
# 284                    59 St-Columbus Circle (A,B,C,D,1)
# 316    Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 331                   Lexington Av-53 St (E,M)/51 St (6)
# 395                                 Flushing-Main St (7)
# 330                   Lexington Av (N,R,W)/59 St (4,5,6)
# 276               47-50 Sts-Rockefeller Center (B,D,F,M)
# 369    74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...
# 275                   42 St-Bryant Pk (B,D,F,M)/5 Av (7)
# 311                             Canal St (J,N,Q,R,W,Z,6)
# ...

# %%
high_station_2017.unique()
# Out:
# array(['Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', 'Fulton St (A,C,J,Z,2,3,4,5)',
#        '34 St-Penn Station (1,2,3)', '34 St-Penn Station (A,C,E)',
#        '59 St-Columbus Circle (A,B,C,D,1)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        'Lexington Av-53 St (E,M)/51 St (6)', 'Flushing-Main St (7)',
#        'Lexington Av (N,R,W)/59 St (4,5,6)',
#        '47-50 Sts-Rockefeller Center (B,D,F,M)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        '42 St-Bryant Pk (B,D,F,M)/5 Av (7)', 'Canal St (J,N,Q,R,W,Z,6)',
#        '14 St (F,M,1,2,3)/6 Av (L)', '86 St (4,5,6)',
#        '14 St (A,C,E)/8 Av (L)',
#        'West 4 St-Washington Sq (A,B,C,D,E,F,M)'], dtype=object)

# %%
# Get the highest ridership unique values in 2017 respective to stations
riderships_2017_high = riderships_2017_high['2017']

# %%
riderships_2017_high
# Out:
# 341    64815739
# 325    44928488
# 271    39672507
# 243    34557551
# 324    26838473
# 273    26034238
# 274    24366500
# 284    22929203
# 316    20927141
# 331    18940774
# 395    18746832
# 330    17888188
# 276    17471620
# 369    17095073
# 275    16594289
# 311    16285516
# 242    15187056
# 296    14277369
# 241    14153266
# 344    13849130
# Name: 2017, dtype: int64

# %%
riderships_2017_high.unique()
# Out:
# array([64815739, 44928488, 39672507, 34557551, 26838473, 26034238,
#        24366500, 22929203, 20927141, 18940774, 18746832, 17888188,
#        17471620, 17095073, 16594289, 16285516, 15187056, 14277369,
#        14153266, 13849130], dtype=int64)

# %%
fig = px.bar(x=high_station_2017, y = riderships_2017_high, title="20 Busiest Station in 2017")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="018ef16c-f30a-419d-be55-589d958eda43" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("018ef16c-f30a-419d-be55-589d958eda43")) {                    Plotly.newPlot(                        "018ef16c-f30a-419d-be55-589d958eda43",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)", "Grand Central-42 St (S,4,5,6,7)", "34 St-Herald Sq (B,D,F,M,N,Q,R,W)", "14 St-Union Sq (L,N,Q,R,W,4,5,6)", "Fulton St (A,C,J,Z,2,3,4,5)", "34 St-Penn Station (1,2,3)",
# ...

# %% [markdown]
# ### (8) 20 lowest riderships in 2017

# %%
# Let's find out 20 stations have lowest riderships in 2017
riderships_2017_low = riderships_df.sort_values(by=['2017'], ascending = False).tail(20)
riderships_2017_low
# Out:
#                               Station  Unnamed: 1  Unnamed: 2       Boro  \
# 348                      104 St (J,Z)         0.0         0.0     Queens
# 89                          86 St (N)         0.0         0.0   Brooklyn
# 189                    Neptune Av (F)         0.0         0.0   Brooklyn
# 416                     Seneca Av (M)         0.0         0.0     Queens
# 138                 Cypress Hills (J)         0.0         0.0   Brooklyn
# 387                 Beach 90 St (A,S)         0.0         0.0     Queens
# 101                      Avenue U (F)         0.0         0.0   Brooklyn
# 352                      121 St (J,Z)         0.0         0.0     Queens
# 96                       Avenue I (F)         0.0         0.0   Brooklyn
# 378     Aqueduct-North Conduit Av (A)         0.0         0.0     Queens
# 383                   Beach 36 St (A)         0.0         0.0     Queens
# 168                     Junius St (3)         0.0         0.0   Brooklyn
# ...

# %%
# Get the lowest ridership unique values in 2017 respective to stations
low_station_2017 = riderships_2017_low['Station']

# %%
low_station_2017
# Out:
# 348                        104 St (J,Z)
# 89                            86 St (N)
# 189                      Neptune Av (F)
# 416                       Seneca Av (M)
# 138                   Cypress Hills (J)
# 387                   Beach 90 St (A,S)
# 101                        Avenue U (F)
# 352                        121 St (J,Z)
# 96                         Avenue I (F)
# 378       Aqueduct-North Conduit Av (A)
# 383                     Beach 36 St (A)
# 168                       Junius St (3)
# 30         East 143 St-St Mary's St (6)
# 415    Rockaway Park-Beach 116 St (A,S)
# 384                     Beach 44 St (A)
# 107                        Bay Pkwy (F)
# 388                   Beach 98 St (A,S)
# 381                  Beach 105 St (A,S)
# 390                 Broad Channel (A,S)
# 345                   WTC Cortlandt (1)
# Name: Station, dtype: object

# %%
low_station_2017.unique()
# Out:
# array(['104 St (J,Z)', '86 St (N)', 'Neptune Av (F)', 'Seneca Av (M)',
#        'Cypress Hills (J)', 'Beach 90 St (A,S)', 'Avenue U (F)',
#        '121 St (J,Z)', 'Avenue I (F)', 'Aqueduct-North Conduit Av (A)',
#        'Beach 36 St (A)', 'Junius St (3)', "East 143 St-St Mary's St (6)",
#        'Rockaway Park-Beach 116 St (A,S)', 'Beach 44 St (A)',
#        'Bay Pkwy (F)', 'Beach 98 St (A,S)', 'Beach 105 St (A,S)',
#        'Broad Channel (A,S)', 'WTC Cortlandt (1)'], dtype=object)

# %%
# Get the lowest ridership unique values in 2017 respective to stations
riderships_2017_low = riderships_2017_low['2017']

# %%
riderships_2017_low
# Out:
# 348    502541
# 89     494456
# 189    478754
# 416    454373
# 138    435855
# 387    411887
# 101    373322
# 352    337075
# 96     326469
# 378    309029
# 383    298395
# 168    298119
# 30     285667
# 415    235691
# 384    214473
# 107    214153
# 388    180588
# 381     97654
# 390     87774
# 345         0
# Name: 2017, dtype: int64

# %%
riderships_2017_low.unique()
# Out:
# array([502541, 494456, 478754, 454373, 435855, 411887, 373322, 337075,
#        326469, 309029, 298395, 298119, 285667, 235691, 214473, 214153,
#        180588,  97654,  87774,      0], dtype=int64)

# %%
fig = px.bar(x=low_station_2017, y = riderships_2017_low, title="20 Least Riderships Station in 2017")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="da5a5c50-fee5-45c9-919a-72725820999e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da5a5c50-fee5-45c9-919a-72725820999e")) {                    Plotly.newPlot(                        "da5a5c50-fee5-45c9-919a-72725820999e",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["104 St (J,Z)", "86 St (N)", "Neptune Av (F)", "Seneca Av (M)", "Cypress Hills (J)", "Beach 90 St (A,S)", "Avenue U (F)", "121 St (J,Z)", "Avenue I (F)", "Aqueduct-North Conduit Av (A)", "Beach 36 St (A)", "Junius St (3)
# ...

# %%
# Average Ridership in 2017
int(riderships_df['2017'].mean())
# Out:
# 4073772

# %%
# Average Ridership in 20 Busiest Station in 2017
int(riderships_2016_high.mean())
# Out:
# 24917657

# %%
# Average Ridership in 20 Least Busiest Station in 2017
int(riderships_2016_low.mean())
# Out:
# 260816

# %% [markdown]
# ### (9) 20 highest riderships in 2018

# %%
# Let's find out 20 stations have highest riderships in 2018
riderships_2018_high = riderships_df.sort_values(by=['2018'], ascending = False).head(20)
riderships_2018_high
# Out:
#                                                Station  Unnamed: 1  \
# 341   Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)         0.0
# 325                    Grand Central-42 St (S,4,5,6,7)         0.0
# 271                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)         0.0
# 243                   14 St-Union Sq (L,N,Q,R,W,4,5,6)         0.0
# 324                        Fulton St (A,C,J,Z,2,3,4,5)         0.0
# 273                         34 St-Penn Station (1,2,3)         0.0
# 274                         34 St-Penn Station (A,C,E)         0.0
# 284                  59 St-Columbus Circle (A,B,C,D,1)         0.0
# 316  Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...         0.0
# 331                 Lexington Av-53 St (E,M)/51 St (6)         0.0
# 395                               Flushing-Main St (7)         0.0
# 276             47-50 Sts-Rockefeller Center (B,D,F,M)         0.0
# 369  74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...         0.0
# ...

# %%
# Get the highest ridership unique values in 2018 respective to stations
high_station_2018 = riderships_2018_high['Station']

# %%
high_station_2018
# Out:
# 341     Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 325                      Grand Central-42 St (S,4,5,6,7)
# 271                    34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 243                     14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 324                          Fulton St (A,C,J,Z,2,3,4,5)
# 273                           34 St-Penn Station (1,2,3)
# 274                           34 St-Penn Station (A,C,E)
# 284                    59 St-Columbus Circle (A,B,C,D,1)
# 316    Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 331                   Lexington Av-53 St (E,M)/51 St (6)
# 395                                 Flushing-Main St (7)
# 276               47-50 Sts-Rockefeller Center (B,D,F,M)
# 369    74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...
# 330                   Lexington Av (N,R,W)/59 St (4,5,6)
# 275                   42 St-Bryant Pk (B,D,F,M)/5 Av (7)
# 311                             Canal St (J,N,Q,R,W,Z,6)
# ...

# %%
high_station_2018.unique()
# Out:
# array(['Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', 'Fulton St (A,C,J,Z,2,3,4,5)',
#        '34 St-Penn Station (1,2,3)', '34 St-Penn Station (A,C,E)',
#        '59 St-Columbus Circle (A,B,C,D,1)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        'Lexington Av-53 St (E,M)/51 St (6)', 'Flushing-Main St (7)',
#        '47-50 Sts-Rockefeller Center (B,D,F,M)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        'Lexington Av (N,R,W)/59 St (4,5,6)',
#        '42 St-Bryant Pk (B,D,F,M)/5 Av (7)', 'Canal St (J,N,Q,R,W,Z,6)',
#        '14 St (F,M,1,2,3)/6 Av (L)', '14 St (A,C,E)/8 Av (L)',
#        'Atlantic Av-Barclays Ctr (B,D,N,Q,R,2,3,4,5)', '86 St (4,5,6)'],
#       dtype=object)

# %%
# Get the lowest ridership unique values in 2018 respective to stations
riderships_2018_high = riderships_2018_high['2018']

# %%
riderships_2018_high
# Out:
# 341    65060656
# 325    45207849
# 271    39111312
# 243    33124407
# 324    27719115
# 273    25968950
# 274    24857456
# 284    22991014
# 316    21636146
# 331    18585755
# 395    17799862
# 276    17289384
# 369    16994358
# 330    16955204
# 275    16056128
# 311    15995877
# 242    15002214
# 241    14324670
# 94     13807282
# 296    13486510
# Name: 2018, dtype: int64

# %%
riderships_2018_high.unique()
# Out:
# array([65060656, 45207849, 39111312, 33124407, 27719115, 25968950,
#        24857456, 22991014, 21636146, 18585755, 17799862, 17289384,
#        16994358, 16955204, 16056128, 15995877, 15002214, 14324670,
#        13807282, 13486510], dtype=int64)

# %%
fig = px.bar(x=high_station_2018, y = riderships_2018_high, title="20 Busiest Station in 2018")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="e92c696c-459b-4d8f-befb-a72d982b6ab6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e92c696c-459b-4d8f-befb-a72d982b6ab6")) {                    Plotly.newPlot(                        "e92c696c-459b-4d8f-befb-a72d982b6ab6",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)", "Grand Central-42 St (S,4,5,6,7)", "34 St-Herald Sq (B,D,F,M,N,Q,R,W)", "14 St-Union Sq (L,N,Q,R,W,4,5,6)", "Fulton St (A,C,J,Z,2,3,4,5)", "34 St-Penn Station (1,2,3)",
# ...

# %% [markdown]
# ### (10) 20 lowest riderships in 2018

# %%
# Let's find out 20 stations have lowest riderships in 2018
riderships_2018_low = riderships_df.sort_values(by=['2018'], ascending = False).tail(20)
riderships_2018_low
# Out:
#                               Station  Unnamed: 1  Unnamed: 2       Boro  \
# 250           163 St-Amsterdam Av (C)         0.0         0.0  Manhattan
# 382                   Beach 25 St (A)         0.0         0.0     Queens
# 200                       Park Pl (S)         0.0         0.0   Brooklyn
# 100                      Avenue P (F)         0.0         0.0   Brooklyn
# 348                      104 St (J,Z)         0.0         0.0     Queens
# 189                    Neptune Av (F)         0.0         0.0   Brooklyn
# 138                 Cypress Hills (J)         0.0         0.0   Brooklyn
# 352                      121 St (J,Z)         0.0         0.0     Queens
# 387                 Beach 90 St (A,S)         0.0         0.0     Queens
# 96                       Avenue I (F)         0.0         0.0   Brooklyn
# 101                      Avenue U (F)         0.0         0.0   Brooklyn
# 30       East 143 St-St Mary's St (6)         0.0         0.0      Bronx
# ...

# %%
# Get the highest ridership unique values in 2018 respective to stations
low_station_2018 = riderships_2018_low['Station']

# %%
low_station_2018
# Out:
# 250             163 St-Amsterdam Av (C)
# 382                     Beach 25 St (A)
# 200                         Park Pl (S)
# 100                        Avenue P (F)
# 348                        104 St (J,Z)
# 189                      Neptune Av (F)
# 138                   Cypress Hills (J)
# 352                        121 St (J,Z)
# 387                   Beach 90 St (A,S)
# 96                         Avenue I (F)
# 101                        Avenue U (F)
# 30         East 143 St-St Mary's St (6)
# 378       Aqueduct-North Conduit Av (A)
# 383                     Beach 36 St (A)
# 415    Rockaway Park-Beach 116 St (A,S)
# 384                     Beach 44 St (A)
# 107                        Bay Pkwy (F)
# 388                   Beach 98 St (A,S)
# 381                  Beach 105 St (A,S)
# 390                 Broad Channel (A,S)
# Name: Station, dtype: object

# %%
low_station_2018.unique()
# Out:
# array(['163 St-Amsterdam Av (C)', 'Beach 25 St (A)', 'Park Pl (S)',
#        'Avenue P (F)', '104 St (J,Z)', 'Neptune Av (F)',
#        'Cypress Hills (J)', '121 St (J,Z)', 'Beach 90 St (A,S)',
#        'Avenue I (F)', 'Avenue U (F)', "East 143 St-St Mary's St (6)",
#        'Aqueduct-North Conduit Av (A)', 'Beach 36 St (A)',
#        'Rockaway Park-Beach 116 St (A,S)', 'Beach 44 St (A)',
#        'Bay Pkwy (F)', 'Beach 98 St (A,S)', 'Beach 105 St (A,S)',
#        'Broad Channel (A,S)'], dtype=object)

# %%
# Get the lowest ridership unique values in 2018 respective to stations
riderships_2018_low = riderships_2018_low['2018']

# %%
riderships_2018_low
# Out:
# 250    548092
# 382    543839
# 200    537340
# 100    509036
# 348    456765
# 189    433083
# 138    411331
# 352    391696
# 387    382766
# 96     326005
# 101    310821
# 30     301240
# 378    276067
# 383    275165
# 415    240483
# 384    216609
# 107    188225
# 388    154620
# 381     92852
# 390     82248
# Name: 2018, dtype: int64

# %%
riderships_2018_low.unique()
# Out:
# array([548092, 543839, 537340, 509036, 456765, 433083, 411331, 391696,
#        382766, 326005, 310821, 301240, 276067, 275165, 240483, 216609,
#        188225, 154620,  92852,  82248], dtype=int64)

# %%
fig = px.bar(x=low_station_2018, y = riderships_2018_low, title="20 Least Riderships Station in 2018")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="c6c16507-6a66-4ff7-b79c-abd2455cad09" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6c16507-6a66-4ff7-b79c-abd2455cad09")) {                    Plotly.newPlot(                        "c6c16507-6a66-4ff7-b79c-abd2455cad09",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["163 St-Amsterdam Av (C)", "Beach 25 St (A)", "Park Pl (S)", "Avenue P (F)", "104 St (J,Z)", "Neptune Av (F)", "Cypress Hills (J)", "121 St (J,Z)", "Beach 90 St (A,S)", "Avenue I (F)", "Avenue U (F)", "East 143 St-St Mar
# ...

# %%
# Average Ridership in 2018
int(riderships_df['2018'].mean())
# Out:
# 3962436

# %%
# Average Ridership in 20 Busiest Station in 2018
int(riderships_2018_high.mean())
# Out:
# 24098707

# %%
# Average Ridership in 20 Least Busiest Station in 2017
int(riderships_2016_low.mean())
# Out:
# 260816

# %% [markdown]
# ### (11) 20 highest riderships in 2019

# %%
# Let's find out 20 stations have highest riderships in 2019
riderships_2019_high = riderships_df.sort_values(by=['2019'], ascending = False).head(20)
riderships_2019_high
# Out:
#                                                Station  Unnamed: 1  \
# 341   Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)         0.0
# 325                    Grand Central-42 St (S,4,5,6,7)         0.0
# 271                  34 St-Herald Sq (B,D,F,M,N,Q,R,W)         0.0
# 243                   14 St-Union Sq (L,N,Q,R,W,4,5,6)         0.0
# 324                        Fulton St (A,C,J,Z,2,3,4,5)         0.0
# 273                         34 St-Penn Station (1,2,3)         0.0
# 274                         34 St-Penn Station (A,C,E)         0.0
# 284                  59 St-Columbus Circle (A,B,C,D,1)         0.0
# 316  Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...         0.0
# 331                 Lexington Av-53 St (E,M)/51 St (6)         0.0
# 276             47-50 Sts-Rockefeller Center (B,D,F,M)         0.0
# 395                               Flushing-Main St (7)         0.0
# 275                 42 St-Bryant Pk (B,D,F,M)/5 Av (7)         0.0
# ...

# %%
# Get the highest ridership unique values in 2019 respective to stations
high_station_2019 = riderships_2019_high['Station']

# %%
high_station_2019
# Out:
# 341     Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)
# 325                      Grand Central-42 St (S,4,5,6,7)
# 271                    34 St-Herald Sq (B,D,F,M,N,Q,R,W)
# 243                     14 St-Union Sq (L,N,Q,R,W,4,5,6)
# 324                          Fulton St (A,C,J,Z,2,3,4,5)
# 273                           34 St-Penn Station (1,2,3)
# 274                           34 St-Penn Station (A,C,E)
# 284                    59 St-Columbus Circle (A,B,C,D,1)
# 316    Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortla...
# 331                   Lexington Av-53 St (E,M)/51 St (6)
# 276               47-50 Sts-Rockefeller Center (B,D,F,M)
# 395                                 Flushing-Main St (7)
# 275                   42 St-Bryant Pk (B,D,F,M)/5 Av (7)
# 369    74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,...
# 330                   Lexington Av (N,R,W)/59 St (4,5,6)
# 311                             Canal St (J,N,Q,R,W,Z,6)
# ...

# %%
high_station_2019.unique()
# Out:
# array(['Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)',
#        'Grand Central-42 St (S,4,5,6,7)',
#        '34 St-Herald Sq (B,D,F,M,N,Q,R,W)',
#        '14 St-Union Sq (L,N,Q,R,W,4,5,6)', 'Fulton St (A,C,J,Z,2,3,4,5)',
#        '34 St-Penn Station (1,2,3)', '34 St-Penn Station (A,C,E)',
#        '59 St-Columbus Circle (A,B,C,D,1)',
#        'Chambers St (A,C)/WTC (E)/Park Pl (2,3)/Cortlandt (R,W)',
#        'Lexington Av-53 St (E,M)/51 St (6)',
#        '47-50 Sts-Rockefeller Center (B,D,F,M)', 'Flushing-Main St (7)',
#        '42 St-Bryant Pk (B,D,F,M)/5 Av (7)',
#        '74-Broadway (7)/Jackson Hts-Roosevelt Av (E,F,M,R)',
#        'Lexington Av (N,R,W)/59 St (4,5,6)', 'Canal St (J,N,Q,R,W,Z,6)',
#        '14 St (F,M,1,2,3)/6 Av (L)', '14 St (A,C,E)/8 Av (L)',
#        'West 4 St-Washington Sq (A,B,C,D,E,F,M)',
#        'Atlantic Av-Barclays Ctr (B,D,N,Q,R,2,3,4,5)'], dtype=object)

# %%
# Get the highest ridership unique values in 2019 respective to stations
riderships_2019_high = riderships_2019_high['2019']

# %%
riderships_2019_high
# Out:
# 341    65020294
# 325    45745700
# 271    39385436
# 243    32385260
# 324    27715365
# 273    25967676
# 274    25631364
# 284    23040650
# 316    20820549
# 331    18957465
# 276    18604810
# 395    17568837
# 275    17213702
# 369    17077862
# 330    16760813
# 311    15861864
# 242    14736035
# 241    14239275
# 344    14063633
# 94     13939794
# Name: 2019, dtype: int64

# %%
riderships_2019_high.unique()
# Out:
# array([65020294, 45745700, 39385436, 32385260, 27715365, 25967676,
#        25631364, 23040650, 20820549, 18957465, 18604810, 17568837,
#        17213702, 17077862, 16760813, 15861864, 14736035, 14239275,
#        14063633, 13939794], dtype=int64)

# %%
fig = px.bar(x=high_station_2019, y = riderships_2019_high, title="20 Busiest Station in 2019")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="00135c87-fa7f-4bc3-a868-1b04bb449079" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00135c87-fa7f-4bc3-a868-1b04bb449079")) {                    Plotly.newPlot(                        "00135c87-fa7f-4bc3-a868-1b04bb449079",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Times Sq-42 St (N,Q,R,W,S,1,2,3,7)/42 St (A,C,E)", "Grand Central-42 St (S,4,5,6,7)", "34 St-Herald Sq (B,D,F,M,N,Q,R,W)", "14 St-Union Sq (L,N,Q,R,W,4,5,6)", "Fulton St (A,C,J,Z,2,3,4,5)", "34 St-Penn Station (1,2,3)",
# ...

# %% [markdown]
# ### (12) 20 lowest riderships in 2019

# %%
# Let's find out 20 stations have lowest riderships in 2019
riderships_2019_low = riderships_df.sort_values(by=['2019'], ascending = False).tail(20)
riderships_2019_low
# Out:
#                               Station  Unnamed: 1  Unnamed: 2       Boro  \
# 101                      Avenue U (F)         0.0         0.0   Brooklyn
# 347                        104 St (A)         0.0         0.0     Queens
# 354                         21 St (G)         0.0         0.0     Queens
# 260                        215 St (1)         0.0         0.0  Manhattan
# 200                       Park Pl (S)         0.0         0.0   Brooklyn
# 382                   Beach 25 St (A)         0.0         0.0     Queens
# 93                    Atlantic Av (L)         0.0         0.0   Brooklyn
# 189                    Neptune Av (F)         0.0         0.0   Brooklyn
# 138                 Cypress Hills (J)         0.0         0.0   Brooklyn
# 107                      Bay Pkwy (F)         0.0         0.0   Brooklyn
# 351                        111 St (J)         0.0         0.0     Queens
# 387                 Beach 90 St (A,S)         0.0         0.0     Queens
# ...

# %%
# Get the lowest ridership unique values in 2019 respective to stations
low_station_2019 = riderships_2019_low['Station']

# %%
low_station_2019
# Out:
# 101                        Avenue U (F)
# 347                          104 St (A)
# 354                           21 St (G)
# 260                          215 St (1)
# 200                         Park Pl (S)
# 382                     Beach 25 St (A)
# 93                      Atlantic Av (L)
# 189                      Neptune Av (F)
# 138                   Cypress Hills (J)
# 107                        Bay Pkwy (F)
# 351                          111 St (J)
# 387                   Beach 90 St (A,S)
# 30         East 143 St-St Mary's St (6)
# 383                     Beach 36 St (A)
# 378       Aqueduct-North Conduit Av (A)
# 415    Rockaway Park-Beach 116 St (A,S)
# 384                     Beach 44 St (A)
# 388                   Beach 98 St (A,S)
# 390                 Broad Channel (A,S)
# 381                  Beach 105 St (A,S)
# Name: Station, dtype: object

# %%
low_station_2019.unique()
# Out:
# array(['Avenue U (F)', '104 St (A)', '21 St (G)', '215 St (1)',
#        'Park Pl (S)', 'Beach 25 St (A)', 'Atlantic Av (L)',
#        'Neptune Av (F)', 'Cypress Hills (J)', 'Bay Pkwy (F)',
#        '111 St (J)', 'Beach 90 St (A,S)', "East 143 St-St Mary's St (6)",
#        'Beach 36 St (A)', 'Aqueduct-North Conduit Av (A)',
#        'Rockaway Park-Beach 116 St (A,S)', 'Beach 44 St (A)',
#        'Beach 98 St (A,S)', 'Broad Channel (A,S)', 'Beach 105 St (A,S)'],
#       dtype=object)

# %%
# Get the lowest ridership unique values in 2019 respective to stations
riderships_2019_low = riderships_2019_low['2019']

# %%
riderships_2019_low
# Out:
# 101    547776
# 347    536924
# 354    535536
# 260    527505
# 200    519984
# 382    517164
# 93     469819
# 189    428163
# 138    420647
# 107    362802
# 351    350344
# 387    348771
# 30     313938
# 383    292305
# 378    263422
# 415    228144
# 384    215701
# 388    164130
# 390     90358
# 381     88439
# Name: 2019, dtype: int64

# %%
riderships_2019_low.unique()
# Out:
# array([547776, 536924, 535536, 527505, 519984, 517164, 469819, 428163,
#        420647, 362802, 350344, 348771, 313938, 292305, 263422, 228144,
#        215701, 164130,  90358,  88439], dtype=int64)

# %%
fig = px.bar(x=low_station_2019, y = riderships_2019_low, title="20 Least Riderships Station in 2019")
fig.update_xaxes(type='category')
fig.show()
# Out:
# <div>                            <div id="0f4eb049-ad8e-4119-b50c-6683d4edb3dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f4eb049-ad8e-4119-b50c-6683d4edb3dc")) {                    Plotly.newPlot(                        "0f4eb049-ad8e-4119-b50c-6683d4edb3dc",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["Avenue U (F)", "104 St (A)", "21 St (G)", "215 St (1)", "Park Pl (S)", "Beach 25 St (A)", "Atlantic Av (L)", "Neptune Av (F)", "Cypress Hills (J)", "Bay Pkwy (F)", "111 St (J)", "Beach 90 St (A,S)", "East 143 St-St Mary
# ...

# %%
# Average Ridership in 2019
int(riderships_df['2019'].mean())
# Out:
# 4004214

# %%
# Average Ridership in 20 Busiest Station in 2019
int(riderships_2019_high.mean())
# Out:
# 24236819

# %%
# Average Ridership in 20 Least Busiest Station in 2019
int(riderships_2019_low.mean())
# Out:
# 361093

# %%
from geopy.geocoders import Nominatim
from folium.plugins import HeatMap
import folium

# %%
riderships = pd.read_csv('MTA Ridership Data.csv')

# %%
riderships
# Out:
#                                         Station  Unnamed: 1  Unnamed: 2  \
# 0                  138 St-Grand Concourse (4,5)         NaN         NaN
# 1                149 St-Grand Concourse (2,4,5)         NaN         NaN
# 2                 161 St-Yankee Stadium (B,D,4)         NaN         NaN
# 3                                    167 St (4)         NaN         NaN
# 4                                  167 St (B,D)         NaN         NaN
# ..                                          ...         ...         ...
# 419  Sutphin Blvd-Archer Av-JFK Airport (E,J,Z)         NaN         NaN
# 420                  Vernon Blvd-Jackson Av (7)         NaN         NaN
# 421                        Woodhaven Blvd (J,Z)         NaN         NaN
# 422                        Woodhaven Blvd (M,R)         NaN         NaN
# 423                          Woodside-61 St (7)         NaN         NaN
#
#        Boro       2014       2015       2016     2017     2018     2019  \
# ...

# %%
map = folium.Map(location=[40.693943, -73.985880], default_zoom_start=15)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Part 2. Turnstile Analysis

# %% [markdown]
# ## 1. Load the data

# %% [markdown]
# Description:
# * C/A = Control Area (e.g., A002)
# * unit = Remote Unit for a station (e.g., R051)
# * SCP = Subunit Channel Position represents an specific address for a device (e.g., 02-00-00)
# * station_code = C/A + unit, locating a station
# * turnstile = C/A + unit + SCP, locating a turnstile
# * Station = Represents the station name the device is located at
# * date = Represents the date (MM-DD-YY)
# * time = Represents the time (hh:mm:ss) for a scheduled audit event
# * datetime = date + time (MM-DD-YY hh:mm:ss)
# * desc = Represent the "REGULAR" scheduled audit event (Normally occurs every 4 hours)
# * entries = The comulative entry register value for a device
# * exits = The cumulative exit register value for a device

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
turnstile = pd.read_csv('turnstile_170401.csv')

# %%
turnstile
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# ...       ...   ...       ...            ...      ...      ...        ...
# 198363  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198364  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198365  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198366  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198367  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
#
#             TIME     DESC  ENTRIES    EXITS
# ...

# %%
# before convert datetime format, checking the unique value for date
turnstile['DATE'].unique()
# Out:
# array(['3/25/2017', '3/26/2017', '3/27/2017', '3/28/2017', '3/29/2017',
#        '3/30/2017', '3/31/2017'], dtype=object)

# %%
turnstile['DATETIME'] = pd.to_datetime(turnstile.DATE + ' ' + turnstile.TIME, format='%m/%d/%Y  %H:%M:%S')
turnstile['turnstile'] = turnstile['C/A'] + '-' + turnstile['UNIT'] + '-' + turnstile['SCP']

turnstile = turnstile[(turnstile.DATETIME >= '01-01-17 00:00:00') & 
          (turnstile.DATETIME <'07-01-17 00:00:00')]

# %%
turnstile
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION       DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  3/25/2017
# ...       ...   ...       ...            ...      ...      ...        ...
# 198363  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198364  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198365  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198366  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
# 198367  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  3/31/2017
#
#             TIME     DESC  ENTRIES    EXITS            DATETIME  \
# ...

# %% [markdown]
# ## 2. Checking and Hangling Missing Values

# %%
turnstile.isnull().sum()
# Out:
# C/A          0
# UNIT         0
# SCP          0
# STATION      0
# LINENAME     0
# DIVISION     0
# DATE         0
# TIME         0
# DESC         0
# ENTRIES      0
# EXITS        0
# DATETIME     0
# turnstile    0
# dtype: int64

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %%
# The description shows how many people enter or exit for the station
print("The description of the entries: ")
print(turnstile['ENTRIES'].describe())
print("The description of the exits: ")
print(turnstile['EXITS'].describe())
# Out:
# The description of the entries:
# count    1.983680e+05
# mean     3.608106e+07
# std      1.961768e+08
# min      0.000000e+00
# 25%      4.876508e+05
# 50%      2.619187e+06
# 75%      6.694274e+06
# max      2.130569e+09
# Name: ENTRIES, dtype: float64
# The description of the exits:
# count    1.983680e+05
# mean     2.879460e+07
# std      1.773091e+08
# min      0.000000e+00
# 25%      2.370978e+05
# 50%      1.465094e+06
# 75%      4.722654e+06
# max      2.087387e+09
# Name: EXITS, dtype: float64

# %%
## gets the number of entries and exits
entries = turnstile.groupby(['STATION','C/A','UNIT','SCP','DATE']).ENTRIES.max() - turnstile.groupby(['STATION','C/A','UNIT','SCP','DATE']).ENTRIES.min()
exits = turnstile.groupby(['STATION','C/A','UNIT','SCP','DATE']).EXITS.max() - turnstile.groupby(['STATION','C/A','UNIT','SCP','DATE']).EXITS.min()

# %%
entries
# Out:
# STATION    C/A   UNIT  SCP       DATE
# 1 AV       H007  R248  00-00-00  3/25/2017    2021
#                                  3/26/2017    1728
#                                  3/27/2017    3378
#                                  3/28/2017    3674
#                                  3/29/2017    3700
#                                               ...
# ZEREGA AV  R419  R326  00-05-01  3/27/2017       0
#                                  3/28/2017       0
#                                  3/29/2017       0
#                                  3/30/2017       0
#                                  3/31/2017       0
# Name: ENTRIES, Length: 32842, dtype: int64

# %%
exits
# Out:
# STATION    C/A   UNIT  SCP       DATE
# 1 AV       H007  R248  00-00-00  3/25/2017    3513
#                                  3/26/2017    3030
#                                  3/27/2017    3738
#                                  3/28/2017    3820
#                                  3/29/2017    3801
#                                               ...
# ZEREGA AV  R419  R326  00-05-01  3/27/2017       1
#                                  3/28/2017       0
#                                  3/29/2017       0
#                                  3/30/2017       0
#                                  3/31/2017       0
# Name: EXITS, Length: 32842, dtype: int64

# %%
## reset the index
entries = entries.reset_index()
exits = exits.reset_index()

mta_entries_exits = pd.merge(entries, exits, how='outer')

# %%
mta_entries_exits
# Out:
#          STATION   C/A  UNIT       SCP       DATE  ENTRIES  EXITS
# 0           1 AV  H007  R248  00-00-00  3/25/2017     2021   3513
# 1           1 AV  H007  R248  00-00-00  3/26/2017     1728   3030
# 2           1 AV  H007  R248  00-00-00  3/27/2017     3378   3738
# 3           1 AV  H007  R248  00-00-00  3/28/2017     3674   3820
# 4           1 AV  H007  R248  00-00-00  3/29/2017     3700   3801
# ...          ...   ...   ...       ...        ...      ...    ...
# 32837  ZEREGA AV  R419  R326  00-05-01  3/27/2017        0      1
# 32838  ZEREGA AV  R419  R326  00-05-01  3/28/2017        0      0
# 32839  ZEREGA AV  R419  R326  00-05-01  3/29/2017        0      0
# 32840  ZEREGA AV  R419  R326  00-05-01  3/30/2017        0      0
# 32841  ZEREGA AV  R419  R326  00-05-01  3/31/2017        0      0
#
# [32842 rows x 7 columns]

# %%
plt.figure(figsize=(20, 20))
plt.subplot(2, 2, 2)
mta_entries_exits['ENTRIES'].value_counts().plot(kind='kde')
plt.title('Entries distribution graph')
# Out:
# Text(0.5, 1.0, 'Entries distribution graph')

# %%
plt.figure(figsize=(20, 20))
plt.subplot(2, 2, 2)
mta_entries_exits['EXITS'].value_counts().plot(kind='kde')
plt.title('Exits distribution graph')
# Out:
# Text(0.5, 1.0, 'Exits distribution graph')

# %% [markdown]
# ## 4. Hypothesis Testing

# %%
turnstile_weather = pd.read_csv('turnstile_data_master_with_weather.csv')

# %%
turnstile_weather
# Out:
#         UNIT       DATE      TIME  Hour     DESC  ENTRIES  EXITS  \
# 0       R001   5/1/2011   1:00:00     1  REGULAR        0      0
# 1       R001   5/1/2011   5:00:00     5  REGULAR      217    553
# 2       R001   5/1/2011   9:00:00     9  REGULAR      890   1262
# 3       R001   5/1/2011  13:00:00    13  REGULAR     2451   3708
# 4       R001   5/1/2011  17:00:00    17  REGULAR     4400   2501
# ...      ...        ...       ...   ...      ...      ...    ...
# 131946  R552  5/30/2011  23:21:29    23  REGULAR       19     14
# 131947  R552  5/30/2011  23:23:30    23  REGULAR      158   1022
# 131948  R552  5/30/2011  23:28:44    23  REGULAR       54    275
# 131949  R552  5/30/2011  23:35:45    23  REGULAR       59     46
# 131950  R552  5/30/2011  23:50:47    23  REGULAR      123    108
#
#         maxpressurei  maxdewpti  mindewpti  ...  meandewpti  meanpressurei  \
# 0              30.31         42         35  ...          39          30.27
# ...

# %%
turnstile_weather.columns
# Out:
# Index(['UNIT', 'DATE', 'TIME', 'Hour', 'DESC', 'ENTRIES', 'EXITS',
#        'maxpressurei', 'maxdewpti', 'mindewpti', 'minpressurei', 'meandewpti',
#        'meanpressurei', 'fog', 'rain', 'meanwindspdi', 'mintempi', 'meantempi',
#        'maxtempi', 'precipi', 'thunder'],
#       dtype='object')

# %% [markdown]
# * Perform Hypothesis Test to test which features do depend on Entries or Exits

# %%
import scipy.stats as stats
# T-test to check whether Hour depend on Entries or not
Ho = "Hour does not depend on Entries"   # Stating the Null Hypothesis
H1 = "Hour depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['Hour'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -168.5595402949283

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# Hour depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
import scipy.stats as stats
# T-test to check whether Hour depend on Entries or not
Ho = "Hour does not depend on Exits"   # Stating the Null Hypothesis
H1 = "Hour depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['Hour'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -158.42026675501947

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# Hour depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %% [markdown]
# * Hour does depends on both Entries and Exists
# * How about the other features?

# %%
# T-test to check whether maxpressurei depend on Entries or not
Ho = "maxpressurei does not depend on Entries"   # Stating the Null Hypothesis
H1 = "maxpressurei depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxpressurei'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -165.58593782270137

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxpressurei depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
Ho = "maxpressurei does not depend on Exists"   # Stating the Null Hypothesis
H1 = "maxpressurei depends on Exists"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxpressurei'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -154.96055462154845

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxpressurei depends on Exists as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether minpressurei depend on Entries or not
Ho = "minpressurei does not depend on Entries"   # Stating the Null Hypothesis
H1 = "minpressurei depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['minpressurei'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -165.60757082537734

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# minpressurei depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxpressurei depend on Exits or not
Ho = "maxpressurei does not depend on Entries"   # Stating the Null Hypothesis
H1 = "maxpressurei depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['minpressurei'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -154.9857246504921

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxpressurei depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxdewpti depend on Entries or not
Ho = "maxdewpti does not depend on Entries"   # Stating the Null Hypothesis
H1 = "maxdewpti depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxdewpti'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -161.35554680525948

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxdewpti depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxdewpti depend on Exits or not
Ho = "maxdewpti does not depend on Exits"   # Stating the Null Hypothesis
H1 = "maxdewpti depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxdewpti'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -150.0383787597954

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxdewpti depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxdewpti depend on Entries or not
Ho = "mindewpti does not depend on Entries"   # Stating the Null Hypothesis
H1 = "mindewpti depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxdewpti'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -161.35554680525948

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# mindewpti depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether mindewpti depend on Exits or not
Ho = "mindewpti does not depend on Exits"   # Stating the Null Hypothesis
H1 = "mindewpti depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxdewpti'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -150.0383787597954

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# mindewpti depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meanpressurei depend on Entries or not
Ho = "meanpressurei does not depend on Entries"   # Stating the Null Hypothesis
H1 = "meanpressurei depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meanpressurei'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -165.59632332521335

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meanpressurei depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meanpressurei depend on Exits or not
Ho = "meanpressurei does not depend on Entries"   # Stating the Null Hypothesis
H1 = "meanpressurei depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meanpressurei'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -154.9726381706039

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meanpressurei depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxdewpti depend on Entries or not
Ho = "meandewpti does not depend on Entries"   # Stating the Null Hypothesis
H1 = "meandewpti depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxdewpti'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -161.35554680525948

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meandewpti depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meandewpti depend on Exits or not
Ho = "meandewpti does not depend on Exits"   # Stating the Null Hypothesis
H1 = "meandewpti depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meandewpti'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -150.85860467802752

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meandewpti depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether fog depend on Entries or not
Ho = "fog does not depend on Entries"   # Stating the Null Hypothesis
H1 = "fog depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['fog'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -170.2279267676725

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# fog depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether fog depend on Exits or not
Ho = "fog does not depend on Exits"   # Stating the Null Hypothesis
H1 = "fog depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['fog'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -160.36151694654583

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# fog depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether rain depend on Entries or not
Ho = "rain does not depend on Entries"   # Stating the Null Hypothesis
H1 = "rain depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['rain'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -170.2019454696472

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# rain depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether rain depend on Exits or not
Ho = "rain does not depend on Exits"   # Stating the Null Hypothesis
H1 = "rain depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['rain'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -160.33128751428654

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# rain depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meanwindspdi depend on Entries or not
Ho = "meanwindspdi does not depend on Entries"   # Stating the Null Hypothesis
H1 = "meanwindspdi depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meanwindspdi'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -169.3922626193983

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meanwindspdi depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meanwindspdi depend on Exits or not
Ho = "meanwindspdi does not depend on Exits"   # Stating the Null Hypothesis
H1 = "meanwindspdi depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meanwindspdi'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -159.3892137174823

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meanwindspdi depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether mintempi depend on Entries or not
Ho = "mintempi does not depend on Entries"   # Stating the Null Hypothesis
H1 = "mintempi depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['mintempi'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -161.52264018186344

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# mintempi depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether mintempi depend on Exits or not
Ho = "mintempi does not depend on Exits"   # Stating the Null Hypothesis
H1 = "mintempi depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['mintempi'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -150.2328436743601

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# mintempi depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxtempi depend on Entries or not
Ho = "maxtempi does not depend on Entries"   # Stating the Null Hypothesis
H1 = "maxtempi depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxtempi'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -159.09759374105684

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxtempi depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether maxtempi depend on Exits or not
Ho = "maxtempi does not depend on Exits"   # Stating the Null Hypothesis
H1 = "maxtempi depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['maxtempi'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -147.41127762633423

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# maxtempi depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meantempi depend on Entries or not
Ho = "meantempi does not depend on Entries"   # Stating the Null Hypothesis
H1 = "meantempi depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meantempi'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -160.26359680350058

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meantempi depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether meantempi depend on Exits or not
Ho = "meantempi does not depend on Exits"   # Stating the Null Hypothesis
H1 = "meantempi depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['meantempi'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -148.7679422841006

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# meantempi depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether precipi depend on Entries or not
Ho = "precipi does not depend on Entries"   # Stating the Null Hypothesis
H1 = "precipi depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['precipi'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -170.2271214836236

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# precipi depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether precipi depend on Exits or not
Ho = "precipi does not depend on Exits"   # Stating the Null Hypothesis
H1 = "precipi depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['precipi'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -160.3605799189515

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# precipi depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether thunder depend on Entries or not
Ho = "thunder does not depend on Entries"   # Stating the Null Hypothesis
H1 = "thunder depends on Entries"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['thunder'])  
y = np.array(turnstile_weather['ENTRIES']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -170.25390186849594

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# thunder depends on Entries as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %%
# T-test to check whether thunder depend on Exits or not
Ho = "thunder does not depend on Exits"   # Stating the Null Hypothesis
H1 = "thunder depends on Exits"   # Stating the Alternate Hypothesis

x = np.array(turnstile_weather['thunder'])  
y = np.array(turnstile_weather['EXITS']) 

t, p_value  = stats.ttest_ind(x,y, axis = 0)  #Performing an Independent t-test

# %%
print("The p value is", p_value)
# Out:
# The p value is 0.0

# %%
print("The t value is", t)
# Out:
# The t value is -160.3917392658151

# %%
if p_value < 0.05:  # Setting our significance level at 5%
    print(f'{H1} as the p_value ({p_value}) < 0.05 and Reject the Null Hypothesis')
else:
    print(f'{Ho} as the p_value ({p_value}) > 0.05 and Accept the Null Hypotheis')
# Out:
# thunder depends on Exits as the p_value (0.0) < 0.05 and Reject the Null Hypothesis

# %% [markdown]
# ## 5. Conclusion
# * All the features depend on both Entries and Exists, which means that weather conditions and hour are all related to Entries and Exists (riderships).
